# %%
# !pip install pandas
# !pip install psycopg2

# %%
import pandas as pd
import psycopg2 
import decimal

# %%
data=pd.read_csv('items/new.csv')

# %%
# data.info()
dropped_col=data.drop(columns='contract')
data=dropped_col

# %%
data=data.dropna()
col=data.columns
trans_col=[x.replace('time (edt)', 'time_edt') for x in col]
data.columns=trans_col

# %%
import psycopg2 
with open('secret.txt') as f:
    file = f.readlines()

secret = [x.split('=')[1].strip() for x in file]

def db_connection():
    try:
        conn=psycopg2.connect(
            database=secret[0],
            user=secret[1],
            host=secret[2],
            password=secret[3]
            port=secret[4]
    )
        print(f'Successfully connected to database')
    except Exception as e:
        print(f'connection failed ==>{e}')

    return conn

connection =db_connection()
cusor =connection.cursor()

# %%
data_metal=pd.read_csv('items/metal.csv')

# %%
data_metal
# Out:
#     Unnamed: 0                       name     units       price  change  \
# 0            0               Gold (Comex)  USD/t oz    2,310.60    1.00
# 1            1               Gold (Tokyo)     JPY/g   11,363.00 -209.00
# 2            2                  Gold Spot  USD/t oz    2,302.60   -1.23
# 3            3             Gold/Euro Spot  EUR/t oz    2,145.79   -0.30
# 4            4    Gold/British Pound Spot  GBP/t oz    1,836.09   -1.83
# 5            5     Gold/Japanese Yen Spot  JPY/t oz  353,075.31 -892.97
# 6            6     Gold/Indian Rupee Spot  INR/t oz  192,181.13  143.59
# 7            7             Silver (Comex)  USD/t oz       26.88    0.05
# 8            8             Silver (Tokyo)  JPY/gram      134.00   -1.10
# 9            9                Silver Spot  USD/t oz       26.67   -0.01
# 10          10           Silver/Euro Spot  EUR/t oz       24.84    0.04
# 11          11  Silver/British Pound Spot  GBP/t oz       21.26   -0.03
# ...

# %%
#use this the method pd.to_numeric if the data or column contain NaN values.
# pd.to_numeric(data_metal['price'].str.replace(',','').astype(float),errors='coerce') 
# data_metal['price']=data_metal['price'].apply(lambda x: decimal.Decimal(x.replace(',', '')))
data_metal['price']=data_metal['price'].replace(',','').astype(float)

# %%
metaldf=pd.read_csv('items/metal_data.csv')

# %%
metaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   21 non-null     int64
#  1   name         21 non-null     object
#  2   units        21 non-null     object
#  3   price        21 non-null     float64
#  4   change       21 non-null     float64
#  5   perc_change  21 non-null     float64
#  6   time_edt     21 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
# Out:
# <class 'pandas.core.series.Series'>
